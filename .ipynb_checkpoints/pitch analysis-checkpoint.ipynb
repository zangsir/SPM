# %% [markdown]
# # automate pitch estimation

# %%
import re
from os import listdir
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
inputname='pitch'
onlyfiles = [ f for f in listdir(inputname) if f.endswith(".pitch")]
#f=open('CHJ000014','r').read()
#fl=f.split('\n')

# %%
num_file=len(onlyfiles)
num_plot=num_file
#plot 4 per row
while num_plot%4!=0:
    num_plot+=1
#plot a by b matrix
a=4
b=num_plot/a

# %%
def gen_xy(pitch_file):
    """from a pitch file, return a list of times, and a list of pitch values"""
    f=open(pitch_file,'r').read()
    fl=f.split('\n')
    times=[]
    pitches=[]
    for line in fl:
        if re.search('number =',line):
            times.append(line.split(' = ')[1].replace(' ',''))
        if re.search('value =',line):
            pitches.append(line.split(' = ')[1].replace(' ',''))
    assert(len(times)==len(pitches))
    return times,pitches

# %%
p,q=gen_xy('pitch/'+onlyfiles[0])

# %%
print p[:10]
print q[:10]
# Out:
# ['0.4820000000000001', '0.4821000000000001', '0.4822000000000001', '0.4823000000000001', '0.4824000000000001', '0.4825000000000001', '0.4826000000000001', '0.4827000000000001', '0.4828000000000001', '0.4829000000000001']
# ['147.6945665023253', '147.68998717957925', '147.67625006322504', '147.65335770864914', '147.62131437394936', '147.58012601861378', '147.5389491553898', '147.50693064932662', '147.48406454216732', '147.47034657933386']

# %%
times=[]
pitches=[]
for line in fl:
    if re.search('number =',line):
        times.append(line.split(' = ')[1].replace(' ',''))
    if re.search('value =',line):
        pitches.append(line.split(' = ')[1].replace(' ',''))

# %%
len(times)
# Out:
# 4951

# %%
len(pitches)
# Out:
# 4951

# %%
plt.plot(times,pitches)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Simple data to display in various forms
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

plt.close('all')

# Just a figure and one subplot
f, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Simple plot')

# Two subplots, the axes array is 1-d
f, axarr = plt.subplots(2, sharex=True)
axarr[0].plot(x, y)
axarr[0].set_title('Sharing X axis')
axarr[1].scatter(x, y)

# Two subplots, unpack the axes array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

# Three subplots sharing both x/y axes
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing both axes')
ax2.scatter(x, y)
ax3.scatter(x, 2 * y ** 2 - 1, color='r')
# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but bottom plot.
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# row and column sharing
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex='col', sharey='row')
ax1.plot(x, y)
ax1.set_title('Sharing x per column, y per row')
ax2.scatter(x, y)
ax3.scatter(x, 2 * y ** 2 - 1, color='r')
ax4.plot(x, 2 * y ** 2 - 1, color='r')

# Four axes, returned as a 2-d array
f, axarr = plt.subplots(2, 2)
axarr[0, 0].plot(x, y)
axarr[0, 0].set_title('Axis [0,0]')
axarr[0, 1].scatter(x, y)
axarr[0, 1].set_title('Axis [0,1]')
axarr[1, 0].plot(x, y ** 2)
axarr[1, 0].set_title('Axis [1,0]')
axarr[1, 1].scatter(x, y ** 2)
axarr[1, 1].set_title('Axis [1,1]')
# Fine-tune figure; hide x ticks for top plots and y ticks for right plots
plt.setp([a.get_xticklabels() for a in axarr[0, :]], visible=False)
plt.setp([a.get_yticklabels() for a in axarr[:, 1]], visible=False)

# Four polar axes
plt.subplots(2, 2, subplot_kw=dict(projection='polar'))

plt.show()

# %% [markdown]
# # code writeup

# %%
import re
from os import listdir
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plot_matrix(xs,ys,i,j):
    f, axarr = plt.subplots(i,j)
    axarr[i, j].plot(xs, ys)
    
    
    
def gen_xy(pitch_file):
    """from a pitch file, return a list of times, and a list of pitch values"""
    f=open(pitch_file,'r').read()
    fl=f.split('\n')
    times=[]
    pitches=[]
    for line in fl:
        if re.search('number =',line):
            times.append(line.split(' = ')[1].replace(' ',''))
        if re.search('value =',line):
            pitches.append(line.split(' = ')[1].replace(' ',''))
    assert(len(times)==len(pitches))
    return times,pitches

# %%
inputname='pitch'
onlyfiles = [ f for f in listdir(inputname) if f.endswith(".pitch")]
print onlyfiles
# Out:
# ['pitcCHJ000014.pitch', 'pitcCHJ000018.pitch', 'pitcCHJ000019.pitch', 'pitcCHJ000025.pitch', 'pitcCHJ000032.pitch']

# %%
ls
# Out:
# pitch/                pitch.pdf             speech-scripts/
# pitch analysis.ipynb  pitchest.praat        test/

# %%
num_file=len(onlyfiles)
num_plot=num_file
num_per_row=2
#plot num_per_row per row
while num_plot%num_per_row!=0:
    num_plot+=1
#plot a by b matrix
b=2
a=num_plot/b


f, axarr = plt.subplots(a,b)
i=j=0
for file in onlyfiles:
    print i,j
    xs,ys=gen_xy(inputname+'/'+file)
    axarr[i, j].plot(xs, ys)
    if j==b-1:
        i+=1
        j=0
    else:
        j+=1

f.savefig('pitch.pdf')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-6b0b380e20d8> in <module>()
#      10
#      11
# ---> 12 f, axarr = plt.subplots(a,b)
#      13 i=j=0
#      14 for file in onlyfiles:
#
# /Users/zangsir/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1184
#    1185     # Create first subplot separately, so we can share it if requested
# -> 1186     ax0 = fig.add_subplot(gs[0, 0], **subplot_kw)
#    1187     axarr[0] = ax0
#    1188
#
# /Users/zangsir/anaconda/lib/python2.7/site-packages/matplotlib/gridspec.pyc in __getitem__(self, key)
#     162                     k2 += ncols
#     163                 if k2 >= ncols or k2 < 0 :
# --> 164                     raise IndexError("index out of range")
#     165                 col1, col2 = k2, k2+1
#     166
#
# IndexError: index out of range

# %% [markdown]
# # pitch trimming algo

# %%
ls
# Out:
# README.md             pitch analysis.ipynb  test/
# gen_textgd.py         pitch_plot.py         test-small/
# get_pitch.praat       pitchest.praat
# pitch/                run-get-pitch.sh*

# %% [markdown]
# ### try to get boxplot info (like in R) from the pitch track data and trim them

# %%
#what's in the boxplot
median = np.median(data)
upper_quartile = np.percentile(data, 75)
lower_quartile = np.percentile(data, 25)

iqr = upper_quartile - lower_quartile
upper_whisker = data[data<=upper_quartile+1.5*iqr].max()
lower_whisker = data[data>=lower_quartile-1.5*iqr].min()

# %%
cd ~/Desktop/speech-exp-diuss/pitch/
# Out:
# /Users/zangsir/Desktop/speech-exp-diuss/pitch

# %%
f=open('pitcCHJ000032.pitch_simple.tab','r').read().split('\n')

# %%
print len(f)
print f[:3]
# Out:
# 31543
# ['time\tpitch', '0.25000000000000033\t241.59326063289845', '0.2501000000000003\t241.5824914037857']

# %%
time=[]
pitch=[]
for i in range(1,len(f)):
    line=f[i]
    if line!="":
        split=line.split('\t')
        #print split
        time.append(float(split[0]))
        pitch.append(float(split[1]))

# %%
B=plt.boxplot(pitch)
ydata=[item.get_ydata() for item in B['whiskers']]
print ydata
# Out:
# [array([ 103.3837109 ,   78.54592702]), array([ 169.72725852,  254.68913103])]

# %%
upper=ydata[1][1] #this is the upper whisker

# %%
#understanding what is in this boxplot
for k,v in B.iteritems():
    print k,v
# Out:
# boxes [<matplotlib.lines.Line2D object at 0x108fc2610>]
# fliers [<matplotlib.lines.Line2D object at 0x108fdb810>]
# medians [<matplotlib.lines.Line2D object at 0x108fdb1d0>]
# means []
# whiskers [<matplotlib.lines.Line2D object at 0x108d6bc10>, <matplotlib.lines.Line2D object at 0x108fc2e90>]
# caps [<matplotlib.lines.Line2D object at 0x108fcf510>, <matplotlib.lines.Line2D object at 0x108fcfb50>]

# %% [markdown]
# ### seems like what we need to try is to trim everything above ydata[1][1]

# %%
plt.plot(time,pitch)

# %%
#however, notice that in this case there a lot of values (spurious) in the boxplot that is caused by interpolation.
#first, remove the spurious points
#then, interpolate
new_pitch=[]
new_time=[]
for i in range(len(pitch)):
    if pitch[i]<=upper:
        new_pitch.append(pitch[i])
        new_time.append(time[i])
    
        
plt.plot(new_time,new_pitch)

# %%
n=0
for i in new_pitch:
    if i<0:
        n+=1
print n
# Out:
# 1399

# %%
from scipy.interpolate import interp1d
x = np.linspace(0, 10, num=11, endpoint=True)
y = np.cos(-x**2/9.0)
#x=new_time
#y=new_pitch
f = interp1d(x, y)
f2 = interp1d(x, y, kind='cubic')

# %%
>>> xnew = np.linspace(0, 10, num=41, endpoint=True)
>>> import matplotlib.pyplot as plt
>>> plt.plot(x, y, 'o', xnew, f(xnew), '-', xnew, f2(xnew), '--')
>>> plt.legend(['data', 'linear', 'cubic'], loc='best')
>>> plt.show()

# %%
len(y)
# Out:
# 11

# %%
dir(f)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_call',
#  '_call_linear',
#  '_call_nearest',
#  '_call_spline',
#  '_check_bounds',
#  '_evaluate',
#  '_finish_y',
#  '_kind',
#  '_prepare_x',
#  '_reshape_yi',
#  '_set_dtype',
#  '_set_yi',
#  '_y',
#  '_y_axis',
#  '_y_extra_shape',
#  'axis',
#  'bounds_error',
#  'copy',
#  'dtype',
#  'fill_value',
#  'x',
#  'y']

# %%
len(f.y)
# Out:
# 11

# %%
len(f2.y)
# Out:
# 11

# %%
len(xnew)
# Out:
# 41

# %%
f(xnew)
# Out:
# array([ 1.        ,  0.99845838,  0.99691675,  0.99537513,  0.99383351,
#         0.97108755,  0.94834159,  0.92559563,  0.90284967,  0.81221283,
#         0.72157599,  0.63093915,  0.54030231,  0.35385005,  0.16739779,
#        -0.01905446, -0.20550672, -0.38776657, -0.57002643, -0.75228628,
#        -0.93454613, -0.86432051, -0.79409488, -0.72386925, -0.65364362,
#        -0.32313274,  0.00737814,  0.33788902,  0.6683999 ,  0.67040116,
#         0.67240241,  0.67440367,  0.67640492,  0.27952113, -0.11736267,
#        -0.51424647, -0.91113026, -0.65452771, -0.39792516, -0.1413226 ,
#         0.11527995])

# %%
fp=interp1d(new_time,new_pitch)

# %%
plt.plot(new_time, new_pitch, 'o', time, fp(time), '-')
# Out:
# [<matplotlib.lines.Line2D at 0x108830750>,
#  <matplotlib.lines.Line2D at 0x1087b32d0>]

# %%
f, (ax1, ax2,ax3) = plt.subplots(3, 1,sharey=True)
ax1.scatter(new_time, new_pitch)

ax2.plot(time, fp(time), '-')
ax3.plot(time,pitch)
#f.savefig('pitch-001-75-interp.pdf')

# %%
ls
# Out:
# pitcCHJ000018.pitch             pitcCHJ000051.pitch
# pitcCHJ000019.pitch             pitcCHJ000110.pitch
# pitcCHJ000025.pitch             pitcCHJ000131.pitch
# pitcCHJ000032.pitch             pitcCHX000171.pitch
# pitcCHJ000032.pitch_simple.tab  pitcDIL000343.pitch
# pitcCHJ000037.pitch             pitcSHH000410.pitch
# pitcCHJ000040.pitch             pitcXUL000031.pitch
# pitcCHJ000046.pitch             pitch-001-75-interp.pdf

# %%
print len(new_time),len(new_pitch)
print len(time),len(fp(time))
# Out:
# 30142 30142
# 31541 31541

# %%
fptime=fp(time)

# %%
fptime[:100]
# Out:
# array([ 241.59326063,  241.5824914 ,  241.5501866 ,  241.49635485,
#         241.42101056,  241.32417387,  241.22737602,  241.15211565,
#         241.09837262,  241.06613255,  241.05538682,  241.03594465,
#         240.97762756,  240.88046375,  240.74450024,  240.56980277,
#         240.39523207,  240.25954245,  240.16266818,  240.10456237,
#         240.08519689,  240.04000365,  239.90447496,  239.67876383,
#         239.36312496,  238.95791428,  238.55338956,  238.23923272,
#         238.01508832,  237.88070291,  237.83592464,  237.79737354,
#         237.68175773,  237.48918961,  237.21985633,  236.87401945,
#         236.52868676,  236.26044277,  236.06902619,  235.95425069,
#         235.9160046 ,  235.89113459,  235.8165403 ,  235.6922689 ,
#         235.51839895,  235.29504033,  235.07189353,  234.89848123,
#         234.77469363,  234.70045239,  234.67571052,  234.64184109,
#         234.54026211,  234.37106151,  234.13438573,  233.83043945,
#         233.52688775,  233.29106444,  233.12276504,  233.02184368,
#         232.98821294,  232.86905844,  232.51196044,  231.91801359,
#         231.08903607,  230.02756033,  228.97096033,  228.15251688,
#         227.56970613,  227.22073454,  227.10452964,  227.00851282,
#         226.72070586,  226.24183824,  225.5731223 ,  224.71624819,
#         223.86262904,  223.20094547,  222.7295121 ,  222.44713016,
#         222.35308243,  222.29522218,  222.12173175,  221.83288187,
#         221.42912298,  220.91108405,  220.39425708,  219.99311663,
#         219.70703483,  219.53556436,  219.47843727,  219.45978899,
#         219.40385365,  219.31065975,  219.1802548 ,  219.01270522,
#         218.84528372,  218.71515549,  218.62225412,  218.56653225])

# %%
print len(time),len(new_time)
# Out:
# 31541 30142

# %% [markdown]
# ### try to get the pitch data without interpolation and see if works better or not
